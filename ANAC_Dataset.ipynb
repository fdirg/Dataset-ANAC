# %%
# Analisis de los datos oficiales otorgados por la ANAC (Administración Nacional de Aviación Civil)

# Fuente: https://datos.gob.ar/dataset/transporte-aterrizajes-despegues-procesados-por-administracion-nacional-aviacion-civil-anac

# %%
# Importamos las libreras a utilizar

import pandas as pd
import requests
import io

# %%
# Creamos un dic con la lista de las URL de los Datasets.

urls_data = {
    '2019': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/aa8337de-3565-4ecf-9cd9-6f1c61f8f0ed/download/2019_informe_ministerio.csv',
    '2020': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/d0e75e7d-e416-470f-bedb-ef2a877cbae3/download/2020_informe_ministerio.csv',
    '2021': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/1b4f569a-cab0-4560-993c-5bf96c3e7cf0/download/202112_informe_ministerio.csv',
    '2022': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/11894a35-de36-4579-b084-d1191f551fbe/download/202212-informe-ministerio.csv',
    '2023': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/e910fead-ade3-40ce-ae8f-cad2017aa007/download/202312-informe-ministerio-actualizado-dic.csv',
    '2024': 'https://datos.transporte.gob.ar/dataset/21038a1a-c3c7-4494-b76a-3a2a8fbb83b5/resource/6004191c-83ca-4a0a-a687-c059bb0a8c8e/download/202404-informe-ministerio.csv'
}

# %%
# En base a un bucle FOR creamos los diferentes DF, diferenciadolos por su año.

for anio, url in urls_data.items():
    response = requests.get(url)
    if response.status_code == 200:
        # Delimitamos las columnas de cada DF
        delimiter = ',' if anio == '2021' else ';'
        df = pd.read_csv(io.BytesIO(response.content), delimiter=delimiter)
        # Se crea cada df por año
        vars()[f'df_{anio}'] = df
    else:
        print('Error')
# Out:
# C:\Users\Federico\AppData\Local\Temp\ipykernel_12020\3733975752.py:8: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(io.BytesIO(response.content), delimiter=delimiter)
# C:\Users\Federico\AppData\Local\Temp\ipykernel_12020\3733975752.py:8: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(io.BytesIO(response.content), delimiter=delimiter)

# %%
# Creamos una lista con todos los DF 

dataframes = [df_2019, df_2020, df_2021, df_2022, df_2023, df_2024]

# Vemos los primeros datos de cada DF

for df in dataframes:
    print(df.head())
# Out:
#       Fecha  Hora UTC Clase de vuelos (todos los vuelos) Clasificacion Vuelo  \
# 0  1/1/2019  00:01:00                            REGULAR           Doméstico
# 1  1/1/2019  00:01:00                            REGULAR       Internacional
# 2  1/1/2019  00:03:00                            REGULAR           Doméstico
# 3  1/1/2019  00:04:00                            REGULAR       Internacional
# 4  1/1/2019  00:06:00                            REGULAR       Internacional
#
#   Tipo Movimiento Aeropuerto Origen/Destino  \
# 0      Aterrizaje        EZE            SAL
# 1      Aterrizaje        EZE           SBGL
# 2      Aterrizaje        AER            SIS
# 3      Aterrizaje        EZE           SBGR
# 4      Aterrizaje        AER           SBGR
#
#                            Aerolinea Nombre          Aeronave  Pasajeros  PAX  \
# 0                  AEROLINEAS ARGENTINAS SA      BO-B-737-76N         88   44
# 1           TRANSPORTES AEREOS DEL MERCOSUR               NaN        165  165
# 2  AUSTRAL LINEAS AEREAS-CIELOS DEL SUR S.A  EMB-ERJ190100IGW         22   11
# 3           TRANSPORTES AEREOS DEL MERCOSUR               NaN         69   69
# 4       LAN ARGENTINA S.A. (LATAM AIRLINES)     AIB-A-320-233         53   53
#
#   Calidad del dato
# 0       DEFINITIVO
# 1       DEFINITIVO
# 2       DEFINITIVO
# 3       DEFINITIVO
# 4       DEFINITIVO
#       Fecha Hora UTC Clase de Vuelo (todos los vuelos) Clasificación Vuelo  \
# 0  1/1/2020    00:06                           Regular       Internacional
# 1  1/1/2020    00:08                           Regular       Internacional
# 2  1/1/2020    00:10                           Regular           Doméstico
# 3  1/1/2020    00:13                           Regular       Internacional
# 4  1/1/2020    00:13                           Regular           Doméstico
#
#   Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0         Aterrizaje        EZE             LEMD
# 1           Despegue        EZE             SCEL
# 2         Aterrizaje        PAL              BAR
# 3           Despegue        EZE             KDFW
# 4         Aterrizaje        PAL              DOZ
#
#                       Aerolinea Nombre Aeronave  Pasajeros  PAX Calidad dato
# 0     IBERIA - LINEAS AÉREAS DE ESPAÑA        0        239  239   DEFINITIVO
# 1  LAN ARGENTINA S.A. (LATAM AIRLINES)        0        152  152   DEFINITIVO
# 2               JETSMART AIRLINES S.A.        0        116   58   DEFINITIVO
# 3               AMERICAN AIRLINES INC.        0        255  255   DEFINITIVO
# 4               JETSMART AIRLINES S.A.        0        146   73   DEFINITIVO
#         Fecha Hora UTC     Clase de Vuelo (todos los vuelos)  \
# 0  01/01/2021    00:02  Vuelo Privado con Matrícula Nacional
# 1  01/01/2021    00:24                               Regular
# 2  01/01/2021    00:26                               Regular
# 3  01/01/2021    00:29                               Regular
# 4  01/01/2021    00:37                               Regular
#
#   Clasificación Vuelo Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0           Doméstico           Despegue        PAR              ROS
# 1           Doméstico         Aterrizaje        EZE              GRA
# 2           Doméstico         Aterrizaje        EZE              ECA
# 3           Doméstico         Aterrizaje        EZE              SAL
# 4           Doméstico         Aterrizaje        EZE              TUC
#
#            Aerolinea Nombre          Aeronave  Pasajeros  PAX Calidad dato
# 0                         0      PA-PA-28-181          0    0   DEFINITIVO
# 1  AEROLINEAS ARGENTINAS SA       BO-B737-8MB        140   70   DEFINITIVO
# 2  AEROLINEAS ARGENTINAS SA        BO-737-800        140   70   DEFINITIVO
# 3  AEROLINEAS ARGENTINAS SA      BO-B-737-76N         24   12   DEFINITIVO
# 4  AEROLINEAS ARGENTINAS SA  EMB-ERJ190100IGW         52   26   DEFINITIVO
#     Fecha UTC Hora UTC Clase de Vuelo (todos los vuelos) Clasificación Vuelo  \
# 0  01/01/2022    00:01                           Regular           Doméstico
# 1  01/01/2022    00:05                           Regular           Doméstico
# 2  01/01/2022    00:05                           Regular           Doméstico
# 3  01/01/2022    00:09                           Regular           Doméstico
# 4  01/01/2022    00:09                           Regular       Internacional
#
#   Tipo de Movimiento Aeropuerto Origen / Destino          Aerolinea Nombre  \
# 0         Aterrizaje        AER              ECA  AEROLINEAS ARGENTINAS SA
# 1         Aterrizaje        AER              SAL  AEROLINEAS ARGENTINAS SA
# 2           Despegue        IGU              AER    JETSMART AIRLINES S.A.
# 3         Aterrizaje        AER              GAL  AEROLINEAS ARGENTINAS SA
# 4           Despegue        EZE             KDFW    AMERICAN AIRLINES INC.
#
#        Aeronave  Pasajeros  PAX Calidad dato
# 0    BO-737-8SH        138   69   DEFINITIVO
# 1     BO-B737-8        129   65   DEFINITIVO
# 2  AIB-A320-232         82   41   DEFINITIVO
# 3   BO-B737-81D        145   73   DEFINITIVO
# 4             0        261  261   DEFINITIVO
#     Fecha UTC Hora UTC Clase de Vuelo (todos los vuelos) Clasificación Vuelo  \
# 0  01/01/2023     0:01                           Regular       Internacional
# 1  01/01/2023     0:10                           Regular           Doméstico
# 2  01/01/2023     0:15                           Regular       Internacional
# 3  01/01/2023     0:17                           Regular           Doméstico
# 4  01/01/2023     0:19                           Regular           Doméstico
#
#   Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0         Aterrizaje        EZE             LEMD
# 1           Despegue        IGU              EZE
# 2         Aterrizaje        AER             SBPA
# 3         Aterrizaje        SAL              AER
# 4         Aterrizaje        AER              OSA
#
#                    Aerolinea Nombre          Aeronave  Pasajeros  PAX  \
# 0  IBERIA - LINEAS AÉREAS DE ESPAÑA                 0        199  199
# 1            JETSMART AIRLINES S.A.      AIB-A320-232         67   34
# 2          AEROLINEAS ARGENTINAS SA      BO-B-737-76N         36   36
# 3            JETSMART AIRLINES S.A.      AIB-A320-232        168   84
# 4          AEROLINEAS ARGENTINAS SA  EMB-ERJ190100IGW         17    9
#
#   Calidad dato
# 0   DEFINITIVO
# 1   DEFINITIVO
# 2   DEFINITIVO
# 3   DEFINITIVO
# 4   DEFINITIVO
#     Fecha UTC Hora UTC Clase de Vuelo (todos los vuelos) Clasificación Vuelo  \
# 0  01/01/2024    00:02                           Regular       Internacional
# 1  01/01/2024    00:02                           Regular       Internacional
# 2  01/01/2024    00:05                           Regular       Internacional
# 3  01/01/2024    00:08                           Regular       Internacional
# 4  01/01/2024    00:10                           Regular       Internacional
#
#   Tipo de Movimiento Aeropuerto Origen / Destino  \
# 0         Aterrizaje        AER             SBGR
# 1         Aterrizaje        EZE             LFPG
# 2         Aterrizaje        EZE             LEMD
# 3           Despegue        EZE             KJFK
# 4           Despegue        AER             SCEL
#
#                            Aerolinea Nombre Aeronave  Pasajeros  PAX  \
# 0       LATAM AIRLINES BRASIL (exTAM LA SA)        0        145  145
# 1                                AIR FRANCE        0        217  217
# 2          IBERIA - LINEAS AÉREAS DE ESPAÑA        0        168  168
# 3                    AMERICAN AIRLINES INC.        0        272  272
# 4  LATAM AIRLINES GROUP S.A.(exLAN AIRLINE)        0         92   92
#
#   Calidad dato
# 0   DEFINITIVO
# 1   DEFINITIVO
# 2   DEFINITIVO
# 3   DEFINITIVO
# 4   DEFINITIVO

# %%
# Vemos los tipos de datos

for df in dataframes:
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580774 entries, 0 to 580773
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Fecha                               580774 non-null  object
#  1   Hora UTC                            580774 non-null  object
#  2   Clase de vuelos (todos los vuelos)  580774 non-null  object
#  3   Clasificacion Vuelo                 580774 non-null  object
#  4   Tipo Movimiento                     580771 non-null  object
#  5   Aeropuerto                          580774 non-null  object
#  6   Origen/Destino                      580771 non-null  object
#  7   Aerolinea Nombre                    398367 non-null  object
#  8   Aeronave                            489113 non-null  object
#  9   Pasajeros                           580774 non-null  int64
#  10  PAX                                 580774 non-null  int64
#  11  Calidad del dato                    580774 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 53.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212726 entries, 0 to 212725
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha                              212726 non-null  object
#  1   Hora UTC                           212726 non-null  object
#  2   Clase de Vuelo (todos los vuelos)  212726 non-null  object
#  3   Clasificación Vuelo                212726 non-null  object
#  4   Tipo de Movimiento                 212726 non-null  object
#  5   Aeropuerto                         212726 non-null  object
#  6   Origen / Destino                   212726 non-null  object
#  7   Aerolinea Nombre                   212726 non-null  object
#  8   Aeronave                           212726 non-null  object
#  9   Pasajeros                          212726 non-null  int64
#  10  PAX                                212726 non-null  int64
#  11  Calidad dato                       212726 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 19.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328136 entries, 0 to 328135
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha                              328136 non-null  object
#  1   Hora UTC                           328136 non-null  object
#  2   Clase de Vuelo (todos los vuelos)  328136 non-null  object
#  3   Clasificación Vuelo                328136 non-null  object
#  4   Tipo de Movimiento                 328136 non-null  object
#  5   Aeropuerto                         328136 non-null  object
#  6   Origen / Destino                   328136 non-null  object
#  7   Aerolinea Nombre                   328136 non-null  object
#  8   Aeronave                           328136 non-null  object
#  9   Pasajeros                          328136 non-null  int64
#  10  PAX                                328136 non-null  int64
#  11  Calidad dato                       328136 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 30.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477085 entries, 0 to 477084
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha UTC                          477085 non-null  object
#  1   Hora UTC                           477085 non-null  object
#  2   Clase de Vuelo (todos los vuelos)  477085 non-null  object
#  3   Clasificación Vuelo                477085 non-null  object
#  4   Tipo de Movimiento                 477085 non-null  object
#  5   Aeropuerto                         477085 non-null  object
#  6   Origen / Destino                   477085 non-null  object
#  7   Aerolinea Nombre                   477085 non-null  object
#  8   Aeronave                           477085 non-null  object
#  9   Pasajeros                          477085 non-null  int64
#  10  PAX                                477085 non-null  object
#  11  Calidad dato                       477085 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 43.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557152 entries, 0 to 557151
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha UTC                          557152 non-null  object
#  1   Hora UTC                           557152 non-null  object
#  2   Clase de Vuelo (todos los vuelos)  557152 non-null  object
#  3   Clasificación Vuelo                557152 non-null  object
#  4   Tipo de Movimiento                 557152 non-null  object
#  5   Aeropuerto                         557152 non-null  object
#  6   Origen / Destino                   557152 non-null  object
#  7   Aerolinea Nombre                   557152 non-null  object
#  8   Aeronave                           557152 non-null  object
#  9   Pasajeros                          557152 non-null  int64
#  10  PAX                                557152 non-null  int64
#  11  Calidad dato                       557152 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 51.0+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190594 entries, 0 to 190593
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Fecha UTC                          190594 non-null  object
#  1   Hora UTC                           190594 non-null  object
#  2   Clase de Vuelo (todos los vuelos)  190594 non-null  object
#  3   Clasificación Vuelo                190594 non-null  object
#  4   Tipo de Movimiento                 190594 non-null  object
#  5   Aeropuerto                         190594 non-null  object
#  6   Origen / Destino                   190594 non-null  object
#  7   Aerolinea Nombre                   190594 non-null  object
#  8   Aeronave                           190594 non-null  object
#  9   Pasajeros                          190594 non-null  int64
#  10  PAX                                190594 non-null  int64
#  11  Calidad dato                       190594 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 17.4+ MB
# None

# %%
# Creamos un dic para guardar todas las columnas de cada DF para analizar que cada columna sea igual.

columnas_df = {}

# Mediante un bucle FOR obtenemos todas las columnas de todos los DF

for anio, df in vars().items(): 
    if anio.startswith('df_'):
        columnas_df[anio] = tuple(df.columns.tolist())

# Vemos las columnas de cada DF

for anio, columnas in columnas_df.items():
    print(f'Columnas {anio}: {columnas}\n')
# Out:
# Columnas df_2019: ('Fecha', 'Hora UTC', 'Clase de vuelos (todos los vuelos)', 'Clasificacion Vuelo', 'Tipo Movimiento', 'Aeropuerto', 'Origen/Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad del dato')
#
# Columnas df_2020: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2021: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2022: ('Fecha UTC', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2023: ('Fecha UTC', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2024: ('Fecha UTC', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')

# %%
# Renombramos las columnas

rename_columna = {
    'Fecha UTC': 'Fecha',
    'Clase de vuelos (todos los vuelos)': 'Clase de Vuelo',
    'Clasificacion Vuelo': 'Clasificación Vuelo',
    'Tipo Movimiento': 'Tipo de Movimiento',
    'Origen/Destino': 'Origen/Destino',
    'Calidad del dato': 'Calidad dato'
}

# Vamos DF por DF cambiando el nombre de las columnas distintas

for df in dataframes:
    df.rename(columns= rename_columna, inplace=True)

# Repetimos el paso anterior para chequear los cambios

columnas_df = {}

for anio, df in vars().items(): 
    if anio.startswith('df_'):
        columnas_df[anio] = tuple(df.columns.tolist())

for anio, columnas in columnas_df.items():
    print(f'Columnas {anio}: {columnas}\n')
# Out:
# Columnas df_2019: ('Fecha', 'Hora UTC', 'Clase de Vuelo', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen/Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2020: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2021: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2022: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2023: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')
#
# Columnas df_2024: ('Fecha', 'Hora UTC', 'Clase de Vuelo (todos los vuelos)', 'Clasificación Vuelo', 'Tipo de Movimiento', 'Aeropuerto', 'Origen / Destino', 'Aerolinea Nombre', 'Aeronave', 'Pasajeros', 'PAX', 'Calidad dato')

# %%
# Vemos que el formato de la columna hora en el df_2019 y en df_2023 es diferente a los demas

print(df_2019['Hora UTC'].head(), df_2020['Hora UTC'].head(), df_2023['Hora UTC'].head())
# Out:
# 0    00:01:00
# 1    00:01:00
# 2    00:03:00
# 3    00:04:00
# 4    00:06:00
# Name: Hora UTC, dtype: object 0    00:06
# 1    00:08
# 2    00:10
# 3    00:13
# 4    00:13
# Name: Hora UTC, dtype: object 0    0:01
# 1    0:10
# 2    0:15
# 3    0:17
# 4    0:19
# Name: Hora UTC, dtype: object

# %%
# Cambiamos el formato de la hora dentro del df_2019 para que sea igual a los demas

df_2019['Hora UTC'] = df_2019['Hora UTC'].str.slice(0, 5)

# Cambiamos el formato de la hora dentro del df_2023 para que sea igual a los demas

def formato_hora(hora):
    hora_divida = hora.split(':')
    if len(hora_divida[0]) == 1:
        hora_divida[0] = '0' + hora_divida[0]
    return ':'.join(hora_divida)

df_2023['Hora UTC'] = df_2023['Hora UTC'].apply(formato_hora)

# El formato de la hora dentro de el df_2019 es igual a los demas

print(df_2019['Hora UTC'].head(), df_2020['Hora UTC'].head(), df_2023['Hora UTC'].head())
# Out:
# 0    00:01
# 1    00:01
# 2    00:03
# 3    00:04
# 4    00:06
# Name: Hora UTC, dtype: object 0    00:06
# 1    00:08
# 2    00:10
# 3    00:13
# 4    00:13
# Name: Hora UTC, dtype: object 0    00:01
# 1    00:10
# 2    00:15
# 3    00:17
# 4    00:19
# Name: Hora UTC, dtype: object

# %%
# Concatenamos todos los DF en un solo DF

df = pd.concat(dataframes, ignore_index=True)

# %%
# Cantidad de registros totales

print(f"Cantidad de registros totales: {df.shape[0]}")
# Out:
# Cantidad de registros totales: 2346467

# %%
# Quitamos espacios en blanco

df = df.map(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Creamos una lista con todas las columnas del DF unico

columnas = [
    'Fecha', 
    'Hora UTC', 
    'Clase de Vuelo', 
    'Clasificación Vuelo', 
    'Tipo de Movimiento', 
    'Aeropuerto', 
    'Origen/Destino', 
    'Aerolinea Nombre', 
    'Aeronave', 
    'Pasajeros', 
    'PAX', 
    'Calidad dato'
]

# Visualizamos todos los valores unicos de todas las columnas

for columna in columnas:
    valores_unicos = df[columna].unique()
    print(f"Valores unicos de la columna '{columna}':")
    print(f"{valores_unicos}\n")
# Out:
# Valores unicos de la columna 'Fecha':
# ['1/1/2019' '2/1/2019' '3/1/2019' ... '28/04/2024' '29/04/2024'
#  '30/04/2024']
#
# Valores unicos de la columna 'Hora UTC':
# ['00:01' '00:03' '00:04' ... '04:18' '05:16' '06:16']
#
# Valores unicos de la columna 'Clase de Vuelo':
# ['REGULAR' 'VUELOS PRIVADOS NACIONALES' 'VUELOS OFICIALES NACIONALES'
#  'NO REGULAR' 'VUELOS PRIVADO CON MATRICULA EXTRANJERA' 'TRABAJO AEREO'
#  'VUELOS DE ADIESTRAMIENTO' 'VUELOS ESCUELA'
#  'VUELOS OFICIALES EXTRANJEROS' 'ESCUELA (NO VIGENTE)' nan]
#
# Valores unicos de la columna 'Clasificación Vuelo':
# ['Doméstico' 'Internacional' 'Dom' 'Inter']
#
# Valores unicos de la columna 'Tipo de Movimiento':
# ['Aterrizaje' 'Despegue' nan]
#
# Valores unicos de la columna 'Aeropuerto':
# ['EZE' 'AER' 'TUC' 'MDP' 'DOZ' 'CBA' 'IGU' 'PAL' 'FDO' 'ROS' 'BAR' 'SAL'
#  'NEU' 'ECA' 'GRA' 'SVO' 'JUJ' 'TRC' 'GAL' 'POS' 'STR' 'OSA' 'USU' 'BCA'
#  'TRE' 'SIS' 'FSA' 'SRA' 'VIE' 'CRV' 'CAT' 'ESQ' 'CHP' 'RTA' 'DRY' 'PAR'
#  'JUA' 'CRR' 'SDE' 'MOR' 'UIS' 'LAR' 'MLG' 'DIL' 'BAL' 'RYD' 'DIA' 'TRH'
#  'GOY' 'GPI' 'PTA' 'MDB' 'ARS' 'DOL' 'HDO' 'NIN' 'EAU' 'RIN' 'CUT']
#
# Valores unicos de la columna 'Origen/Destino':
# ['SAL' 'SBGL' 'SIS' ... '2580' 'WBKS' 'SCGC']
#
# Valores unicos de la columna 'Aerolinea Nombre':
# ['AEROLINEAS ARGENTINAS SA' 'TRANSPORTES AEREOS DEL MERCOSUR'
#  'AUSTRAL LINEAS AEREAS-CIELOS DEL SUR S.A' ... 'OMNI SKY S.A.' 'BIMLARY'
#  'PETREOLUM HELICOPTER DE COLOMBIA']
#
# Valores unicos de la columna 'Aeronave':
# ['BO-B-737-76N' nan 'EMB-ERJ190100IGW' 'AIB-A-320-233' 'BO-737-800'
#  'BO-B737-800' 'BO-737-8F2' 'BO-B767-316' 'DC-DC-9-83' 'BO-737-86J'
#  'BO-737-8' 'AIB-A330-202' 'AIB-A-330-223' 'EMB-EMB-500' 'AIB-A-340-313'
#  'BO-B737-8' 'ARH-BO-105S CBS4' 'LJ-60' 'AIB-A330-203' 'BO-737-81D'
#  'BO-737-7BD' 'BO-737-8SH' 'BO-737-8BK' 'BO-737-8HX' 'BO-B737-8SH'
#  'MT-MU-2B-36-A' 'BO-B737-8MB' 'RW-690' 'BO-B737-86J' 'BO-B-737-81D'
#  'ATR-ATR72-212A' 'EUR-AS-350-B2' 'BE-B-200' 'RO-R-44-II' 'DC-MD-83'
#  'HAB-C-90-GTI' 'LJ-45' 'BEL-429' 'DAS-FALCON 900EX' 'BO-737-76N'
#  'PAA-PA-A-31-310' 'BO-B-737-7BD' 'CE-525' 'LJ-31-A' 'FA-SA-227-AC'
#  'BE-E-90' 'BE-400-A' 'BO-B737-8LP' 'BO-B-737-700' 'BO-B737-81D'
#  'BOM-CL-600-2B16' 'DAS-FALCON 2000' 'PAA-PA-A-32R-300' 'CH-BD-100-1A10'
#  'PAA-PA-A-32-300' 'PA-PA-34-200-T' 'BE-58-P' 'HAB-B-200-GT' 'BE-300-LW'
#  'CIR-SR-22' 'PA-PA-12' 'PAA-PA-A-28R201T' 'BE-23' 'RAY-800XP'
#  'PA-PA-32-R-301' 'PA-PA-31-T' 'GU-GV' 'CE-560-XI' 'BO-B-767-3Q8'
#  'AIB-A330-200' 'FA-SA-227-DC' 'CE-172-B' 'CE-182-A' 'CE-172' 'CE-550'
#  'BE-C-90-A' 'BE-200' 'BO-767-316' 'CE-560' 'DOR-228-202' 'CE-150-L'
#  'BE-C-90-GTI' 'PAA-PA-A-28-R200' 'DH-DHC-6' 'CE-U-206' 'EL-407'
#  'CE-150-K' 'CE-208-B' 'CE-150-M' 'PA-PA-31-350' 'CE-206' 'LJ-LJ45'
#  'PA-PA-28-181' 'EUR-BO 105C CB-4' 'PA-PA-32-300' 'TEA-P2002-JF' 'CE-150'
#  'BE-A-100' 'PA-PA-11' 'GU-GIV-G400-' 'CE-551' 'CE-500' 'PA-PA-28-151'
#  'CE-182-J' 'LJ-31' 'ARH-AS350B3' 'HAW-800-XP' 'LJ-45-XR' 'CE-152'
#  'EUR-MBB-BK-117C2' 'PA-PA-46R-350T' 'MO-M20L' 'CE-172-N'
#  'BOM-CL-600-2B19' 'TXI-172M' 'TEA-P2002 SIERRA' 'CE-A-150-L' 'CE-150-G'
#  'BE-BARON 95-B55' 'RO-R-44' 'PAA-PA-A-32RT300' 'CE-182-T' 'CE-501'
#  'BEL-407' 'CE-150-J' 'PAA-PA-A-38-112' 'PA-PA-46-500TP' 'CIR-SR22 GTS'
#  'CE-525A' 'VA-RV-7' 'EUR-EC-135-T2' 'CE-152-II' 'BE-B-200-GT' 'RO-R66'
#  'PA-PA-38-112' 'CE-210-N' 'CE-182-D' 'BE-B-300' 'CE-P210N'
#  'EXP-EXPRESS CT' 'PA-PA-28-140' 'BE-M-35' 'CE-210-M' 'CE-150-H' 'LJ-25-D'
#  'ARH-MBB-BK117 D-2' 'CE-150-F' 'RW-690-A' 'AET-600-A' 'BO-737-85F'
#  'PA-PA-28R-201' 'BE-36' 'BE-C-90' 'MT-MU-2B-25' 'PAA-PA-A-28-236'
#  'PAA-PA-A-23-250' 'PA-PA-31-310' 'TXA-208B' 'AB-115' 'TEA-P2006T'
#  'PA-PA-39' 'CE-T-210-N' 'CE-182-G' 'PA-PA-34-200' 'CE-170-A' 'LJ-35-A'
#  'TXA-B200GT' 'BE-G36' 'EL-427' 'AET-601-B' 'PAA-PA-A-28-161'
#  'PAA-PA-A-31-T' 'CIT-SR22' 'DDH-LONG-EZ' 'RAY-C90A' 'CE-A-182-K'
#  'TEA-P2008' 'CE-172-M' 'MO-M-20-B' 'BE-58-TC' 'RO-R-66' 'CE-C-152'
#  'TXA-525' 'BE-95-B55' 'CE-AA-150-L' 'TXA-182T' 'CE-182-Q' 'PA-PA-28-161'
#  'EL-206-L-3' 'CE-152-A' 'PA-PA-31-325' 'HDP-UH-1D' 'CE-182-R'
#  'CE-A-185-F' 'PIP-ALPHA TRAINER' 'VAN-RV-6' 'PA-PA-28-R-201T'
#  'PAA-PA-A-28-140' 'BE-C90GT' 'PAA-PA-A-28-R201' 'HDJ-HA-420' 'CE-337-H'
#  'GU-GA-7' 'PA-PA-11-C' 'CE-560-XL' 'RO-R-44RAVEN-I' 'PRP-912I' 'CE-210-E'
#  'PA-PA-28-180' 'WG-WEGA 180' 'CE-172-I' 'TEA-P2002' 'PA-PA-28R-201T'
#  'RO-R-44RAVEN-II' 'CE-T-210-L' 'PAA-PA-A-28-181' 'LON-BIPLAZA'
#  'CE-172-RG' 'CE-550-B' 'AIR-AT-802' 'PA-PA-28-180-D' 'PI-PC-12'
#  'HAB-HAWKER-900XP' 'CE-172-A' 'BOM-BD-100-1A10' 'EUR-AS-350-B3'
#  'CE-C-172-L' 'LBG-SH2' 'PA-PA-34-220-T' 'EUR-AS-355-F3' 'AEP-ATR-42-320'
#  'MO-M-20-J' 'CE-T20GH' 'CE-340A' 'LA-LA-4-200' 'BE-C-90-B' 'CE-206-B'
#  'WSK-PZL-M18B' 'CE-172-K' 'GR-AA5A-CHEETAH' 'CE-T-337-C' 'CE-182'
#  'BE-V-35-B' 'TEA-P2008-JC' 'TXA-560XL' 'CE-C-172-M' 'BE-BARON 55'
#  'HAB-G-58' 'PA-PA-28R-200' 'LJ-60-XR' 'BE-58' 'PA-PA-31P-350' 'CE-TR-182'
#  'CE-A-188' 'CE-U-206-G' 'CE-A-182-J' 'CE-680' 'BE-35-B33' 'BE-BARON 58'
#  'BE-A-36' 'CE-402-C' 'CE-A-182-L' 'CE-510' 'FA-SA-226-TC' 'PA-PA-28R-180'
#  'PA-PA-46-600TP' 'CE-310-R' 'EUR-EC-135T2' 'PA-PA-31' 'CIR-SR20'
#  'GU-G IV-X G450' 'VEL-SUV' 'CE-182-C' 'CE-182-B' 'BEL-206-B'
#  'RRA-COYOTE-S-6ES' 'CE-210-D' 'CE-208' 'HAB-BEECHJET-400' 'PA-PA-24-180'
#  'PI-PC-12-47E' 'BE-E55' 'EL-206-B' 'BE-B-90' 'CE-A-188-B' 'BE-56-TC'
#  'PAA-PA-A-31-350' 'CE-650' 'CE-A-182-N' 'AET-601-P'
#  'TEA-P2002 SIERRA MKII' 'BE-C-23' 'RH-369HS' 'CE-182-P' 'BE-36-A'
#  'EUR-EC-120-B' 'CE-177-B' 'CIR-SR 22T' 'CC-LY' 'CE-T-210-K'
#  'EDD-SUPER PETREL' 'AB-180-RVR' 'SAA-ERCO SAAD' 'CE-337-A' 'AGW-AW 109SP'
#  'CE-P-206-C' 'AB-95' 'CE-C-182P' 'PA-PA-32R-301T' 'BE-S-35' 'BO-B737-7Q8'
#  'LPA-AW169' 'RAY-C-90-GT' 'VA-RV6' 'VA-RV10' 'PAA-PA-A-34-200T'
#  'TEA-P92 EAGLET G5' 'AIB-EC135' 'CE-337' 'ECU-AS-350-B3' 'CE-T-206-H'
#  'BE-B-36-TC' 'BE-F-33-A' 'BE-J35' 'TEA-P92 ECHO CLA' 'BE-G58' 'CRO-490'
#  'CE-182-E' 'EL-430' 'BOM-CL601-3A' 'BE-35-A33' 'RW-500-S' 'SED-MOMIDOS'
#  'HAB-C-90-A' 'CE-R-172-K' 'EMB-EMB-145LR' 'PAA-PA-A-34-220T' 'CE-170'
#  'MO-M20R' 'BE-35-C33A' 'CE-402-B' 'PAA-PA-A-23-250F' 'CE-172-E'
#  'MO-M-20-C' 'BE-V-35-A' 'CE-C-150-L' 'APK-A-22LS' 'PAA-PA-A-28-180'
#  'CE-172-P' 'ARH-MBB-BK117 C2' 'RW-DARTER-100' 'PA-PA-18' 'CE-172-S'
#  'CE-172-H' 'PAA-PA-A-31-325' 'EL-407 GXP' 'SNX-SONEX' 'AIR-AT-802A'
#  'CE-210-G' 'EUR-EC-30-B4' 'EAE-EA500' 'TXA-B200' 'BL-7KCAB' 'HAF-HA-420'
#  'PZL-M-18-B' 'TEA-P2010' 'EL-412-EP' 'LJ-35A' 'CE-210-J' 'TEA-P92 EAGLET'
#  'EL-206-B-III' 'CE-182-H' 'CE-A172N' 'CE-551-CITATION'
#  'EV-SPORT STAR MAX' 'CE-206-H' 'VA-RV6A' 'ZLI-Z-242L' 'EFL-EA300'
#  'PA-PA-23-250' 'BOM-CL600-2B16' 'AIR-AT-802-A' 'BOM-BD-700-1A11'
#  'CE-C-337-G' 'BEL-505' 'CE-402' 'ARH-EC155B1' 'VA-RV-9A' 'BEL-407-GX'
#  'BE-BARON 95-C55' 'CZE-PIPERSPORT' 'BE-D-95-A' 'PAA-PA-A-25-235'
#  'BE-65-B-80' 'SLG-SLING 4' 'AIB-A320-214' 'MO-M-20-F' 'MT-MU-2B-60'
#  'PAA-PA-A-28-235' 'CE-T240' 'PA-PA-24-400' 'CE-337-F' 'CE-170-B'
#  'PTL-912LSA' 'CE-210' 'PA-PA-28-200R' 'PA-PA-30' 'BE-95-A55'
#  'BE-BARON D-55' 'SLG-SLING 2' 'PA-PA-32-260' 'CE-205' 'BE-B-35'
#  'CE-A-188-A' 'BE-BARON E-55' 'BE-90-A' 'PIP-VIRUS-SW' 'BO-B737-8BK'
#  'EUR-MBB-BK-117C1' 'CE-180' 'CE-310-N' 'AMV-AA-1A' 'BE-A36TC'
#  'AG-A-109-E' 'CE-P-210-N' 'TXA-58' 'BE-F-35' 'CE-T-303' 'RW-690-B'
#  'PA-PA-46-350-P' 'PA-PA-24-250' 'ADG-MBB-BK-117C2' 'TEA-ASTORE'
#  'CE-310-Q' 'CE-210-L' 'CE-AA-150' 'RO-44 RAVEN II' 'TXA-208'
#  'PA-PA-23-160' 'AIR-AT-502-B' 'AG-A-109-A-II' 'TXA-172M' 'CE-P-201-N'
#  'CE-R-172-G' 'MO-MA-20-J' 'CE-310' 'BEF-F-90' 'BE-65-A-90' 'CE-R-182'
#  'PA-PA-36-285' 'BE-95-55' 'EUR-BO-105-CBS4' 'BE-BARON B-55' 'I.A-1124'
#  'CE-172-L' 'BE-DUKE B-60' 'RW-690-C' 'WEA-620' 'CE-210-K' 'CIR-L-75'
#  'RQ-RANQUEL' 'AEP-AS 350 B2' 'AB-115-AG' 'LU-8-E' 'CE-182-F' 'CE-T-188-C'
#  'AYR-S2R-T34' 'PA-PA-18A-150' 'RAY-HAWKER 800XP' 'BE-C-35' 'CE-180-H'
#  'VAN-RV-7' 'LAN-320' 'PAA-PA-A-36-300' 'AIR-AT-401' 'TXA-T206H'
#  'EUR-AS-355-F2' 'PA-PA-46R-350' 'AIR-AT-402-B' 'BRT-LSA' 'AIB-A320-232'
#  'MC-BO-105-S' 'CE-182-S' 'BE-N-35' 'CE-175' 'EB-EL BOYERO' 'CE-140'
#  'FL-XP2-503' 'BE-95' 'CA-N-90' 'FA-MERLIN III-B' 'LAN-IV-P' 'RO-R-44 I'
#  'YAK-YAK-55M' 'HAV-RV-6A' 'GR-AA1-A' 'PUE-PA-25-235' 'RQ-SUPERRANQUEL'
#  'PZL-PW-5' 'CE-CE-172RG' 'CI-7B' 'PA-PA-22-108' 'CE-T182T' 'HAB-400-A'
#  'CE-150-A' 'BE-V-35' 'BE-35' 'BEL-222B' 'AK-PITTS S-2A' 'CE-182-L'
#  'WHR-EXPRESS' 'BO-737-200' 'LAI-PA-25-235' 'II-1123' 'TXA-182P'
#  'GR-AA-1C-LYNX' 'BES-SKYRANGER NINJA' 'CE-310-I' 'ES-480B' 'RW-100-150'
#  'CE-TU-206-F' 'GRO-G-103-A' 'PA-PA-28-235' 'CE-T-210-M' 'PTZ-MS 1/3'
#  'BE-G-35' 'BE-BARON B-58' 'PA-PA-25-235' 'EUR-BO-105-S' 'AE-7-EC'
#  'SEV-RV6A' 'PA-J-4-E' 'II-ARAVA 102' 'PA-PA-28-RT201T' 'PZL-M-18-A'
#  'LAV-PA-25-260' 'BE-A-35' 'PA-PA-22' 'TXA-U-206-G' 'LJ-25-C'
#  'TEA-P2002 LSA' 'MC-BO-105-CBS' 'TWC-500-C' 'EX-EA-300-L' 'MO-M-20-E'
#  'PA-PA-18-150' 'CE-188' 'EE-MC FLY' 'CE-T-337-H' 'PT-S1-11B' 'HER-EAGLE'
#  'VSC-RV-4' 'BL-7ECA' 'GUO-VM' 'EUR-EC-145' 'BE-BARON 58-P' 'MO-MARK-21'
#  'CE-C-150-M' 'ANS-S-10' 'RSA-S9 CHAOS AR' 'BE-1900D' 'CE-C-177RG'
#  'RNB-KR2S' 'MO-M20TN' 'ARH-EC 130 T2' 'ER-415-CD' 'PA-PA-36-300'
#  'BE-C-17-B' 'AIB-A-320-212' 'CE-180-A' 'PZY-PL-2' 'JAF-VARI-EZ'
#  'TSA-S2R-T34' 'CE-310-D' 'FLY-RV7A' 'LJ-35' 'ZIP-SZD-192-A'
#  'EUR-BO-105-CBS' 'GR-G-164-B' 'MAC-MB-308' 'CE-310-G' 'AAA-A' 'LU-8-A'
#  'CE-525B' 'DJI-SO-1221-S' 'VA-RV7A' 'PA-J-3C' 'EV-SPORTSTAR'
#  'SHM-VENTUS-2CM' 'DC-MD-88' 'GRU-BABY III' 'MT-MU-2B-35' 'AIR-AT-602'
#  'LAV-PA-25-235' 'CE-172-F' 'CE-UC-78' 'TRU-S2R-H80' 'BL-8KCAB' 'TXA-B300'
#  'DC-DC-2' 'VAN-RV-10' 'TEA-P92-JS' 'AU-J-5G' 'RO-44' 'LEN-15-S' 0 '0'
#  'PLL-375' 'CE-C-501' 'LLA-IV' 'AB-115-AB' 'BE-A36' 'GU-G-IV' 'VAR-RV-7'
#  'BE-BEECHJET400A' 'EMB-EMB-135BJ' 'BRT-BRISTELL LSA' 'TEA-P2002 MKII'
#  'EUR-BO-105-CBS-5' 'VA-RV 12 XLSA' 'DAS-FALCON 7X' 'WSK-M-18-B' 'AB-180'
#  'CAL-A-9' 'LAI-PA25-260' 'PZM-PL-4A' 'AES-AERO 45' 'DC-DC-9-32'
#  'RAB-S 12 AIRALE' 'TXA-G36' 'VAP-RV-10' 'TSA-S2R-H80' 'CE-C-150-K'
#  'RAP-S-16-SHEKARI' 'TXA-U206C' 'PA-PA-25-150' 'RO-R-22-BETA' 'CE-177'
#  'BE-B-23' 'AVA-A-1' 'DC-DC-9-88' 'ULM-F-16' 'CE-337-B' 'CE-TU-206-E'
#  'VA-RV-8' 'LAI-PA-25-260' 'RO-R-22-MARINER' 'PA-PA-46-350T' 'EX-EA-300'
#  'CE-210-C' 'AG-A-109-C' 'RCK-S-2R' 'CE-421-A' 'RO-R-22-BETA-II'
#  'TRU-S2R-T34' 'TEA-P92 MKII' 'PIP-VIRUS SW 121' 'PJ-PITTS SPECIAL SIS'
#  'BE-C90GTI' 'CE-172-C' 'TXA-G58' 'BO-737-287' 'EON-OLYMPIA' 'CE-310-P'
#  'CE-182-K' 'PZL-106-601-BT' 'FAC-1-3' 'CE-177-RG' 'TSA-S2R' 'CE-172RG'
#  'CE-188-T' 'SOC-TBM-700' 'EL-206-L-4' 'AIR-AT-502A' 'CE-185' 'ULM-M-105'
#  'EV-HARMONY LSA' 'TEA-P92' 'EUR-EC-135-T1' 'FT-2' 'TXA-95-B55' 'CE-210-B'
#  'TEA-P2008 US LSA' 'BO-767-316ER' 'TEA-P92 ECHO MKII' 'BW-FIREFLY-7-15'
#  'FOR-F-1' 'BO-737-8Q8' 'BRT-BRISTELL S-LSA' 'TEA-P2002 SIERRA MK2'
#  'THM-BIPLAZA' 'PUM-SPECIAL NORTE' 'BO-B-737-7SV' 'AMA-8K-CAB'
#  'ST-150-VOYAGER' 'TEA-P2012 TRAVELLER' 'BRI-312-F' 'PZL-DROMAER-M18'
#  'LO-L-18-50' 'BEL-412-EP' 'LSA-JA-1' 'CE-T210M' 'CE-175-A'
#  'MC-BO-105S-CBS4' 'SIT-ELECTRO' 'SM-NIMBUS-3DM' 'SBB-340-A' 'TXA-R182'
#  'HU-269-B' 'CE-175-B' 'AYR-S2R-G10' 'ARH-MBB-BK117 D-3' 'RES-TIPO-COYOTE'
#  'TXA-A-36' 'PA-PA-25-260' 'BE-35-33' 'LO-60' 'EVE-HARMONY LSA'
#  'BO-737-8AL' 'FW-44-J' 'II-1121-B' 'CE-336' 'TA-BC-12-D' 'CE-337G'
#  'PRP-PETREL 912LSA' 'SLC-SLICK 360' 'PA-PA-25' 'TEA-P2002JF'
#  'AIR-AT-401-B' 'QU-QUICKIE-I' 'PA-PA-18-A' 'GR-G-164-A' 'JAS-SZD-48-1'
#  'PIT-AIR CAMPER' 'BE-70' 'DIF-912TG' 'RAG-S6ES-COYOTE' 'SI-SIPA 1000'
#  'PT-S-2B' 'TEA-P92 CLASSIC DELUXE' 'TXA-172RG' 'TSA-S2R-T15'
#  'AVD-AVID FLYER' 'MS-MS-885' 'WEA-201-B' 'BO-737-8K5' 'CE-150-E'
#  'SC2-269 C (300 C)' 'BT-BN-2B-26' 'RIE-DRV-1' 'GU-AA-5B' 'LO-1649-A'
#  'GU-GIV-X' 'HAB-G-36' 'STA-STANDARD' 'PA-PA-32RT-300' 'NA-NAV-4'
#  'TAN-T-31-B' 'BE-B-45' 'ST-105' 'TEA-P2010 TDI' 'PI-PC-6-B2-H2'
#  'BO-737-86N' 'BE-K-35' 'FA-MK II' 'WA-EQC' 'MO-M20C' 'BO-PT-17'
#  'NC-1203-II' 'CL-CL-44-D4' 'PA-PA-28-236' 'ADE-ADELANTADA' 'BO-737-2T4'
#  'SS-340-B' 'MIK-MIG-15-UTI' 'CCF-HARVARD MK IV' 'CE-180-G' 'CAM-SWIFT'
#  'BO-PT-17-A-75N1' 'PEZ-PZL-106BT601' 'VAN-RV-8A' 'RAB-S-7' 'TXA-150H'
#  'MN-MONOPLANO' 'PA-PA-24-260' 'RW-680-FL' 'CE-501-CITATION' 'LPA-A 109 E'
#  'BO-737-8U3' 'BE-300' 'AE-7-FC' 'BE-G-36' 'BOW-FLY-BABY-1A' 'RW-500-B'
#  'EFL-EA 300/L' 'LAN-L2KC LEGACY' 'ASF-SA-315-B' 'HI-UH-12-E-4' 'BE-B60'
#  'WEA-620-A' 'MO-M20B' 'BE-28-P' 'BE-F33A' 'INP-NEW CONQUEST'
#  'CUL-CADET LCA' 'BE-C-50' 'SH-S-25' 'TXA-F-33A' 'BE-P-35'
#  'PIP-VIRUS SW121' 'PIT-HM' 'BEF-A36' 'AF-SLING II' 'ZAC-CH 650B'
#  'BST-TDO' 'PAK-SKYBOLT' 'BO-737-228' 'ST-V-77' 'CU-C-46' 'APK-22LS'
#  'DH-DOVE-104' 'ARH-AS-350-B3' 'AV1-RV7' 'HU-269-C' 'CE-320' 'ALO-SE-3130'
#  'ULM-N-300' 'ARH-EC 130 B4' 'AML-AL3' 'PC-AX-6' 'CE-T-310-Q' 'HI-UH-12-E'
#  'CE-A-185-E' 'IGL-RV-7' 'BO-B-75-N1' 'BO-737-8GJ' 'ROL-LS1-D'
#  'DIP-CDP 001' 'DH-DHC-8-102' 'FSU-MS 1/3' 'CAI-480-C' 'TXA-A188A'
#  'GU-AA-5A' 'CE-188-B' 'DIA-DA 42' 'BO-B-737-500' 'RAB-S-19' 'RO-RAVEN I'
#  'EX-EA300/SC' 'PA-PA-12-C' 'PA-PA-28' 'ZAC-CH750 STOL' 'PIP-TAURUS'
#  'RAY-A36' 'DC-DC-4' 'PA-J-3C-65' 'RW-500-U' 'RNS-S-6S-XL'
#  'CL-CL-600-2B19' 'CHI-KA6CR' 'RTA-ACROTEX' 'AIB-A330-243' 'TEA-P-MENTOR'
#  'JAV-PA-18 SUPER CUB' 'ICP-SAVANNAH TM S' 'RW-100-180' 'VAR-RVS7'
#  'DC-DC-9-87' 'CH-CL-6002B16' 'SHF-EXTRA NG' 'SNO-600-S2C'
#  'EMB-PRAETOR 500' 'CE-185-B' 'DUM-BIPLAZA' 'AB-95-115' 'CHN-ND'
#  'TXA-R172K' 'CL-CL-44-6' 'PI-PC-24' 'GRU-BABY II A' 'BE-C-18-S'
#  'PA-L-21-B' 'ULM-H-77' 'BL-7GCBC' 'PZL-106BT-601' 'SLG-4 TSI' 'WA-YKS-6'
#  'AV1-BRISTELL CLASSIC' 'BO-737-200-C' 'TSA-S2R-510' 'VAR-RV-6'
#  'FO-F-28-MK-1000' 'BE-19A' 'AG-AB139' 'BE-65-A' 'DH-PUSS' 'DC-DC-3-C'
#  'TXA-177 RG' 'PA-PA-23' 'LRD-AW119MKII' 'CE-185-A' 'CE-180-B'
#  'SU2-SU 29 AR' 'AIR-AR 401' 'IA-GUARANI G-II' 'BO-737-2P6' 'PA-PA-22-135'
#  'CE-AA-188-B' 'MAX-MH-1521' 'VA-RV4' 'BO-E75' 'CE-180-C' 'CE-C150G'
#  'PZL-M-18' 'CRW-CLASSIC 2020 / RV14A' 'SKI-NYNJA' 'BO-737-3H4' 'RDR-KR2S'
#  'ATR-42-500 (600)' 'DAM-DAUNO' 'VAH-R-V7' 'TEA-P2012' 'HAD-AX8-105'
#  'JS-JS3 RES' 'CE-172-STD' 'RAY-1900D' 'FGA-MS1/3']
#
# Valores unicos de la columna 'Pasajeros':
# [  88  165   22   69   53  156    4  110  272  100  163   59  116  300
#   192    0  104   70  330  226   82  144   38  326  341  206  205  186
#    46  108   50   48   85  125   32  270  234  332   56  232  157  254
#   176  280  148  255  266  242  273    1   24   63  214   98  276  230
#    37   28   84  218  153   13   80  162  124  129   87  133  120   90
#   249   79    6   81  292  115   65  136   23   30  140   78  220  160
#   112  231   71   62  131   54   60  314  196  166   42  215  302  146
#    12   52   74  134   27  126  282  102  135  222  290  168   72  114
#    58  150  128   20  180  132  316  164  184  256  210  298  258  106
#    16  324  204  304   44   86  208  207    2  111  278  152  200  170
#   346  183  350  260  331  121  336   96  328    8  228  262   43  308
#   334  264  320   64  246  322   95  182  312  294  354  122  101  318
#   178  158  338  118  145   76  244  155   61   94  344  225  284  235
#   348  130   77  340  198  250   26  161  342  188    3  238   92  194
#   154  117  167  252  352   66  227   10   75  149  309   25  216  403
#   240  248  274  296  279  172  236  175  138  306  202  268  141   68
#   173   99  209   45  212  412   29  143  142  169   97    7  224   49
#   360  357   73  139  195   83  177  247   55  171  179   93  174   17
#   159  211    5   34  293  351  364  303  288  265  241  271  337  105
#   286  147  237  137  190   18   36  189  281  358   14    9   31  223
#   245  127  233   47  203  382  356  107  119  275   15  368  291  310
#   267  301  406   91  372  361  305  380  109  366  187   40  386   21
#   376   67  251   57  103  323  259  185  217  151  329  283  243   33
#   373  404  269  219  287  374  362  257  123  311  370  402   19  285
#   343  229  191  181  213  263   41  389  113  295  365  261  335  239
#   317  199   89   39  221   51  339  313  197  410   11  325  253  392
#   359  289   35  375  345  297  398  201  353  315  307  378  299  387
#   347  193  405  277  396  349  321  333  413  384  411  395  414  388
#   390  401  355  399  394  327  397  407  367  319  363  418  426  408
#   383  393  428  423  432  430  391  409  400  381  452  474  379  460
#   440 1626  540  369  434  446  480  492  466  458  504  422  416  606
#   442  456  371  536  377  502  421  417  520 1440  420  472  530  498
#   839  542  476  789  385  431  429  439  443  419  438  450  433  441
#   424  437  415  455  475  953  425  435  511  549  701  427]
#
# Valores unicos de la columna 'PAX':
# [44 165 11 69 53 78 2 55 272 50 163 59 116 300 96 0 52 35 113 41 72 19 341
#  103 205 93 23 54 38 24 85 125 16 270 117 166 28 157 254 88 280 148 255
#  133 140 242 273 1 63 214 49 104 276 230 37 84 109 153 13 80 162 62 129 87
#  120 90 249 60 79 32 6 81 146 115 65 68 110 15 39 135 160 45 112 231 71 70
#  131 30 124 218 98 83 21 215 4 151 73 12 26 74 134 27 141 51 111 42 145 31
#  114 29 150 128 20 66 82 158 92 56 210 64 149 106 8 102 152 22 43 207 139
#  76 200 173 183 164 67 175 130 331 121 57 168 48 154 167 58 132 123 25 161
#  95 91 156 147 3 107 292 177 122 101 159 89 169 118 155 61 47 75 172 225
#  142 235 174 77 170 99 171 94 119 46 97 126 176 33 227 5 138 238 309 136
#  108 352 403 100 137 256 296 279 127 86 34 209 36 412 143 7 184 180 188
#  357 195 178 247 179 340 17 211 216 232 252 293 351 182 303 268 10 284 144
#  226 265 332 241 271 337 105 286 237 9 18 192 260 40 189 281 244 198 223
#  212 246 245 233 203 314 191 275 291 310 267 301 294 406 186 361 305 190
#  187 354 193 330 251 236 264 298 323 259 185 217 372 329 283 243 208 373
#  202 269 219 262 287 250 181 266 257 324 290 328 311 402 366 285 343 258
#  278 229 334 213 240 263 274 336 206 308 320 389 234 204 222 304 295 302
#  362 365 14 358 248 261 335 239 317 199 221 386 220 339 313 197 312 410
#  224 194 350 288 325 253 392 359 289 196 375 345 228 342 297 398 201 353
#  282 360 364 315 307 299 387 347 405 277 396 349 321 333 316 356 318 413
#  306 411 374 346 395 348 414 382 401 355 399 338 380 394 404 344 322 327
#  388 397 407 367 319 363 408 383 326 393 423 384 391 378 409 400 381 370
#  376 379 390 813 368 369 371 377 421 416 417 720 839 542 789 385 431 476
#  429 439 443 419 430 438 450 433 441 424 437 415 460 455 475 953 '0' '138'
#  '44' '1' '157' '77' '88' '2' '60' '85' '83' '8' '96' '50' '56' '87' '82'
#  '86' '47' '259' '91' '3' '5' '75' '49' '234' '101' '48' '123' '7' '35'
#  '194' '72' '79' '94' '36' '262' '95' '63' '124' '29' '71' '92' '81' '137'
#  '74' '65' '38' '200' '46' '34' '20' '42' '69' '84' '76' '6' '90' '39'
#  '64' '182' '140' '57' '16' '37' '15' '13' '122' '282' '305' '4' '80' '54'
#  '70' '45' '221' '136' '89' '62' '40' '93' '58' '115' '294' '78' '210'
#  '280' '18' '68' '179' '32' '142' '23' '52' '132' '149' '188' '51' '180'
#  '178' '43' '61' '270' '28' '330' '160' '67' '120' '118' '73' '243' '168'
#  '41' '191' '9' '193' '171' '153' '240' '161' '31' '19' '175' '109' '192'
#  '186' '141' '202' '244' '99' '147' '269' '116' '162' '239' '241' '163'
#  '126' '121' '146' '158' '108' '233' '145' '183' '97' '286' '53' '12'
#  '110' '66' '254' '151' '236' '59' '114' '103' '30' '119' '287' '55' '143'
#  '11' '335' '131' '211' '170' '144' '117' '107' '159' '351' '102' '25'
#  '33' '247' '268' '104' '135' '152' '237' '265' '283' '187' '113' '297'
#  '226' '198' '227' '166' '164' '150' '156' '174' '203' '189' '155' '173'
#  '154' '248' '275' '311' '249' '112' '17' '125' '128' '21' '201' '148'
#  '181' '344' '271' '206' '197' '306' '185' '172' '106' '177' '209' '22'
#  '26' '129' '14' '277' '274' '238' '319' '229' '100' '219' '130' '165'
#  '167' '169' '333' '321' '24' '300' '304' '260' '133' '291' '345' '27'
#  '98' '139' '331' '235' '276' '250' '258' '184' '228' '176' '127' '218'
#  '253' '245' '293' '246' '216' '134' '343' '214' '212' '252' '190' '215'
#  '326' '320' '105' '263' '272' '111' '334' '266' '267' '222' '261' '257'
#  '302' '273' '336' '10' '256' '231' '288' '357' '289' '196' '264' '296'
#  '281' '339' '195' '279' '230' '315' '309' '353' '225' '205' '204' '327'
#  '346' '301' '295' '232' '278' '316' '208' '217' '251' '255' '213' '299'
#  '332' '325' '224' '322' '223' '285' '207' '347' '308' '290' '220' '199'
#  '360' '312' '298' '338' '356' '361' '313' '242' '369' '337' '350' '348'
#  '77,5' '0,5' '90,5' '76,5' '88,5' '85,5' '105,5' '36,5' '84,5' '83,5'
#  '44,5' '93,5' '47,5' '63,5' '87,5' '1,5' '50,5' '89,5' '56,5' '81,5'
#  '57,5' '29,5' '48,5' '64,5' '78,5' '68,5' '72,5' '98,5' '41,5' '66,5'
#  '43,5' '82,5' '12,5' '97,5' '71,5' '74,5' '2,5' '86,5' '45,5' '46,5'
#  '33,5' '40,5' '67,5' '92,5' '27,5' '3,5' '58,5' '73,5' '28,5' '62,5'
#  '112,5' '25,5' '80,5' '54,5' '91,5' '42,5' '95,5' '94,5' '6,5' '5,5'
#  '79,5' '59,5' '65,5' '37,5' '60,5' '70,5' '4,5' '75,5' '9,5' '49,5'
#  '24,5' '39,5' '8,5' '13,5' '69,5' '34,5' '284' '51,5' '30,5' '38,5'
#  '32,5' '35,5' '17,5' '16,5' '19,5' '364' '31,5' '14,5' '20,5' '96,5'
#  '61,5' '314' '53,5' '117,5' '7,5' '21,5' '22,5' '55,5' '52,5' '26,5'
#  '329' '131,5' '310' '15,5' '23,5' '10,5' '18,5' '340' '11,5' '368' '318'
#  '365' '352' '292' '99,5' '341' '106,5' '328' '150,5' '103,5' '104,5'
#  '102,5' '303' '307' '342' '375' '363' '367' '374' '373' '107,5' '349'
#  '372' '317' '371' '366' '358' '324' '355' '359' '354' '362' 428 418 440
#  434 442 426 425 435 549 701 540 427]
#
# Valores unicos de la columna 'Calidad dato':
# ['DEFINITIVO' 'PROVISORIO']

# %%
# Capitalizamos la letra de los valores

df['Clase de Vuelo (todos los vuelos)'] = df['Clase de Vuelo (todos los vuelos)'].str.title()

# Reemplazamos para obtener valores unicos

replace_valor = {
    'Vuelos Privados Nacionales': 'Vuelo Privado con Matrícula Nacional',
    'Vuelos Privado Con Matricula Extranjera': 'Vuelo Privado con Matrícula Extranjera',
    'Vuelo Privado Con Matricula Extranjera': 'Vuelo Privado con Matrícula Extranjera',
    'Vuelos Oficiales Nacionales': 'Vuelo Oficial Nacional',
    'Vuelos Oficiales Extranjeros': 'Vuelo Oficial Extranjero',
    'Vuelos De Adiestramiento': 'Vuelo de Adiestramiento',
    'Vuelo De Adiestramiento': 'Vuelo de Adiestramiento',
    'Trabajo Aereo': 'Trabajo Aéreo',
    'Vuelos Escuela': 'Vuelo Escuela'
}

df['Clase de Vuelo (todos los vuelos)'] = df['Clase de Vuelo (todos los vuelos)'].replace(replace_valor)

df['Clasificación Vuelo'] = df['Clasificación Vuelo'].replace({'Dom': 'Doméstico', 'Inter': 'Internacional'})

# Visualizamos los valores unicos dentro de las columnas donde se reemplazaron los datos

columnas_cambiadas = {
    'Clase de Vuelo (todos los vuelos)',
    'Clasificación Vuelo'
}

for columna in columnas_cambiadas:
    valores_unicos = df[columna].unique()
    print(f"Valores unicos de la columna '{columna}':")
    print(f"{valores_unicos}\n")
# Out:
# Valores unicos de la columna 'Clasificación Vuelo':
# ['Doméstico' 'Internacional']
#
# Valores unicos de la columna 'Clase de Vuelo (todos los vuelos)':
# [nan 'Regular' 'Vuelo Privado Con Matrícula Nacional' 'No Regular'
#  'Vuelo Privado Con Matrícula Extranjera' 'Trabajo Aéreo'
#  'Vuelo de Adiestramiento' 'Vuelo Oficial Extranjero'
#  'Vuelo Oficial Nacional' 'Vuelo Escuela']

# %%
# Analizamos la cantidad de valores NaN

df_nan = df[columnas].isna().sum()

print(df_nan)
# Out:
# Fecha                        0
# Hora UTC                     0
# Clase de Vuelo         1765693
# Clasificación Vuelo          0
# Tipo de Movimiento           3
# Aeropuerto                   0
# Origen/Destino         1765696
# Aerolinea Nombre        182407
# Aeronave                 91661
# Pasajeros                    0
# PAX                          0
# Calidad dato                 0
# dtype: int64

# %%
# Visualizamos las filas con valores NaN dentro de las columnas Tipo de Movimiento y Origen / Destino

print(df[df['Tipo de Movimiento'].isna() & df['Origen / Destino'].isna()])

# Los valores NaN de la columna Tipo de Movimiento y Origen / Destino se encuentran en los mismos registros (3)
# Out:
#              Fecha Hora UTC              Clase de Vuelo Clasificación Vuelo  \
# 110721    8/3/2019    18:05  VUELOS PRIVADOS NACIONALES           Doméstico
# 388994   30/8/2019    19:34              VUELOS ESCUELA           Doméstico
# 564141  19/12/2019    20:54              VUELOS ESCUELA           Doméstico
#
#        Tipo de Movimiento Aeropuerto Origen/Destino Aerolinea Nombre  \
# 110721                NaN        AER            NaN              NaN
# 388994                NaN        ROS            NaN      FLYING TIME
# 564141                NaN        MOR            NaN              NaN
#
#             Aeronave  Pasajeros PAX Calidad dato  \
# 110721      BE-A-100          0   0   DEFINITIVO
# 388994  TEA-P2002-JF          0   0   DEFINITIVO
# 564141      CE-150-J          0   0   DEFINITIVO
#
#        Clase de Vuelo (todos los vuelos) Origen / Destino
# 110721                               NaN              NaN
# 388994                               NaN              NaN
# 564141                               NaN              NaN

# %%
# Cantidad de registros totales antes de eliminar los registros con valores NaN

print(f"Cantidad de registros totales: {df.shape[0]}")
# Out:
# Cantidad de registros totales: 2346467

# %%
# Eliminamos los valores NaN que se encuentran en la columna Tipo de Movimiento y Origen / Destino ya que son solo 3 registros

df = df.dropna(subset=['Tipo de Movimiento'])

# Chequeamos que los registros hayan sido borrados

df_nan = df[columnas].isna().sum()

print(f"{df_nan}")
# Out:
# Fecha                        0
# Hora UTC                     0
# Clase de Vuelo         1765693
# Clasificación Vuelo          0
# Tipo de Movimiento           0
# Aeropuerto                   0
# Origen/Destino         1765693
# Aerolinea Nombre        182405
# Aeronave                 91661
# Pasajeros                    0
# PAX                          0
# Calidad dato                 0
# dtype: int64

# %%
# Cantidad de registros totales despues de los cambios

print(f"Cantidad de registros totales: {df.shape[0]}")
# Out:
# Cantidad de registros totales: 2346464

# %%
# Cantidad de registros repetidos

registros_repetidos = df.duplicated().sum()

print(f"Cantidad de registros repetidos: {registros_repetidos}")
# Out:
# Cantidad de registros repetidos: 4705

# %%
# Visualizamos la filas que contienen los registros repetidos

registros_repetidos = df[df.duplicated()]

print("Filas repetidas:")
print(registros_repetidos)
# Out:
# Filas repetidas:
#               Fecha Hora UTC               Clase de Vuelo Clasificación Vuelo  \
# 1907       2/1/2019    17:26  VUELOS OFICIALES NACIONALES           Doméstico
# 14468     10/1/2019    13:29               VUELOS ESCUELA           Doméstico
# 14629     10/1/2019    15:01               VUELOS ESCUELA           Doméstico
# 18798     12/1/2019    20:45               VUELOS ESCUELA           Doméstico
# 24305     16/1/2019    14:34  VUELOS OFICIALES NACIONALES           Doméstico
# ...             ...      ...                          ...                 ...
# 2345743  30/04/2024    15:32                          NaN       Internacional
# 2345785  30/04/2024    15:52                          NaN           Doméstico
# 2345878  30/04/2024    16:43                          NaN           Doméstico
# 2345991  30/04/2024    17:52                          NaN           Doméstico
# 2346088  30/04/2024    19:00                          NaN           Doméstico
#
#         Tipo de Movimiento Aeropuerto Origen/Destino         Aerolinea Nombre  \
# 1907            Aterrizaje        RTA            SIS                      NaN
# 14468             Despegue        MOR            MOR                      NaN
# 14629             Despegue        MOR            MOR                      NaN
# 18798           Aterrizaje        MOR            MOR                      NaN
# 24305             Despegue        PAR            RTA                      NaN
# ...                    ...        ...            ...                      ...
# 2345743           Despegue        NEU            NaN  AEROCLUB TEMUCO (CHILE)
# 2345785           Despegue        RTA            NaN                        0
# 2345878         Aterrizaje        RTA            NaN                        0
# 2345991           Despegue        RTA            NaN                        0
# 2346088         Aterrizaje        RTA            NaN                        0
#
#          Aeronave  Pasajeros PAX Calidad dato  \
# 1907          NaN          0   0   DEFINITIVO
# 14468      CE-152          0   0   DEFINITIVO
# 14629      CE-152          0   0   DEFINITIVO
# 18798    CE-150-M          0   0   DEFINITIVO
# 24305         NaN          0   0   DEFINITIVO
# ...           ...        ...  ..          ...
# 2345743         0          0   0   PROVISORIO
# 2345785         0          0   0   PROVISORIO
# 2345878         0          0   0   PROVISORIO
# 2345991         0          0   0   PROVISORIO
# 2346088         0          0   0   PROVISORIO
#
#         Clase de Vuelo (todos los vuelos) Origen / Destino
# 1907                                  NaN              NaN
# 14468                                 NaN              NaN
# 14629                                 NaN              NaN
# 18798                                 NaN              NaN
# 24305                                 NaN              NaN
# ...                                   ...              ...
# 2345743                        No Regular             SCPC
# 2345785            Vuelo Oficial Nacional              RTA
# 2345878            Vuelo Oficial Nacional              RTA
# 2345991            Vuelo Oficial Nacional              RTA
# 2346088            Vuelo Oficial Nacional              RTA
#
# [4705 rows x 14 columns]

# %%
# Guardamos el DF

df.to_csv(r'C:\Users\Federico\Desktop\Data\ANAC.csv', index=False)
